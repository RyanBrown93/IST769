# %%
! sudo cp /home/jovyan/work/jars/neo4j-connector-apache-spark_2.12-4.1.0_for_spark_3.jar /usr/local/spark/jars/neo4j-connector-apache-spark_2.12-4.1.0_for_spark_3.jar

# %%
import pyspark
from pyspark.sql import SparkSession
# NEO4J  CONFIGURATION
bolt_url = "bolt://neo4j:7687"
# Spark init
spark = SparkSession.builder \
    .master("local") \
    .appName('jupyter-pyspark') \
    .getOrCreate()
sc = spark.sparkContext
sc.setLogLevel("ERROR")
print(bolt_url)
# Out:
# bolt://neo4j:7687

# %%
cypher_query = '''
MATCH (s:Supplier)-[:SUPPLIES]->(p:Product) 
WHERE s.country = 'USA' AND p.discontinued=false 
RETURN s.contactName, s.companyName, s.country, p.productName, 
p.unitPrice, p.discontinued, p.unitsInStock
'''
df = spark.read.format("org.neo4j.spark.DataSource")\
  .option("url", bolt_url) \
  .option("query", cypher_query) \
  .load()
print(bolt_url)
# Out:
# bolt://neo4j:7687

# %%
df.printSchema()
# Out:
# root
#  |-- s.contactName: string (nullable = true)
#  |-- s.companyName: string (nullable = true)
#  |-- s.country: string (nullable = true)
#  |-- p.productName: string (nullable = true)
#  |-- p.unitPrice: double (nullable = true)
#  |-- p.discontinued: boolean (nullable = true)
#  |-- p.unitsInStock: long (nullable = true)

# %%
df.toPandas()
# Out:
#     s.contactName                s.companyName s.country  \
# 0   Shelley Burke   New Orleans Cajun Delights       USA
# 1   Shelley Burke   New Orleans Cajun Delights       USA
# 2   Shelley Burke   New Orleans Cajun Delights       USA
# 3   Regina Murphy    Grandma Kelly's Homestead       USA
# 4   Regina Murphy    Grandma Kelly's Homestead       USA
# 5   Regina Murphy    Grandma Kelly's Homestead       USA
# 6   Cheryl Saylor            Bigfoot Breweries       USA
# 7   Cheryl Saylor            Bigfoot Breweries       USA
# 8   Cheryl Saylor            Bigfoot Breweries       USA
# 9   Robb Merchant  New England Seafood Cannery       USA
# 10  Robb Merchant  New England Seafood Cannery       USA
# 11  Shelley Burke   New Orleans Cajun Delights       USA
# 12  Shelley Burke   New Orleans Cajun Delights       USA
# 13  Shelley Burke   New Orleans Cajun Delights       USA
# 14  Regina Murphy    Grandma Kelly's Homestead       USA
# 15  Regina Murphy    Grandma Kelly's Homestead       USA
# 16  Regina Murphy    Grandma Kelly's Homestead       USA
# 17  Cheryl Saylor            Bigfoot Breweries       USA
# 18  Cheryl Saylor            Bigfoot Breweries       USA
# 19  Cheryl Saylor            Bigfoot Breweries       USA
# 20  Robb Merchant  New England Seafood Cannery       USA
# 21  Robb Merchant  New England Seafood Cannery       USA
#
#                        p.productName  p.unitPrice  p.discontinued  \
# 0          Louisiana Hot Spiced Okra        17.00           False
# 1       Chef Anton's Cajun Seasoning        22.00           False
# 2   Louisiana Fiery Hot Pepper Sauce        21.05           False
# 3       Grandma's Boysenberry Spread        25.00           False
# 4         Northwoods Cranberry Sauce        40.00           False
# 5    Uncle Bob's Organic Dried Pears        30.00           False
# 6                      Sasquatch Ale        14.00           False
# 7          Laughing Lumberjack Lager        14.00           False
# 8                     Steeleye Stout        18.00           False
# 9    Jack's New England Clam Chowder         9.65           False
# 10                  Boston Crab Meat        18.40           False
# 11      Chef Anton's Cajun Seasoning        22.00           False
# 12  Louisiana Fiery Hot Pepper Sauce        21.05           False
# 13         Louisiana Hot Spiced Okra        17.00           False
# 14   Uncle Bob's Organic Dried Pears        30.00           False
# 15        Northwoods Cranberry Sauce        40.00           False
# 16      Grandma's Boysenberry Spread        25.00           False
# 17                    Steeleye Stout        18.00           False
# 18                     Sasquatch Ale        14.00           False
# 19         Laughing Lumberjack Lager        14.00           False
# 20   Jack's New England Clam Chowder         9.65           False
# 21                  Boston Crab Meat        18.40           False
#
#     p.unitsInStock
# 0                4
# 1               53
# 2               76
# 3              120
# 4                6
# 5               15
# 6              111
# 7               22
# 8               20
# 9               85
# 10             123
# 11              53
# 12              76
# 13               4
# 14              15
# 15               6
# 16             120
# 17              20
# 18             111
# 19              22
# 20              85
# 21             123

# %%
file_name = "file:///home/jovyan/datasets/fudgemart/fudgemart-employees.json"
employees = spark.read.option("multiline", True).json(file_name)
employees.toPandas()
print(file_name)
# Out:
# file:///home/jovyan/datasets/fudgemart/fudgemart-employees.json

# %%
employees.printSchema()
# Out:
# root
#  |-- employee_birthdate: string (nullable = true)
#  |-- employee_department: string (nullable = true)
#  |-- employee_firstname: string (nullable = true)
#  |-- employee_fulltime: string (nullable = true)
#  |-- employee_hiredate: string (nullable = true)
#  |-- employee_hourlywage: double (nullable = true)
#  |-- employee_id: long (nullable = true)
#  |-- employee_jobtitle: string (nullable = true)
#  |-- employee_lastname: string (nullable = true)
#  |-- employee_ssn: string (nullable = true)
#  |-- employee_supervisor_id: long (nullable = true)
#  |-- employee_termdate: string (nullable = true)

# %%
from pyspark.sql.functions import col, concat, lit
employees = spark.read.option("multiline", True).json(file_name) \
    .withColumn("employee_name",concat(col("Employee_firstname"),lit(" "), col("employee_lastname")))
    
tmp = employees.select("employee_id","employee_name", "employee_jobtitle", "employee_department")
print(file_name)
tmp.toPandas()
# Out:
# file:///home/jovyan/datasets/fudgemart/fudgemart-employees.json
#     employee_id          employee_name   employee_jobtitle employee_department
# 0             1            Arial Photo     Sales Associate         Electronics
# 1             2               Sal Ladd     Sales Associate         Electronics
# 2             3          Dustin Dawind     Sales Associate            Hardware
# 3             4           Sandi Shores     Sales Associate            Hardware
# 4             5     Isabelle Gunnering  Department Manager         Electronics
# 5             6           Lee Hvmeehom  Department Manager            Hardware
# 6             7           Allan Wrench     Sales Associate          Housewares
# 7             8             Ally Gator     Sales Associate      Sporting Goods
# 8             9       Alma Frienzergon     Sales Associate          Housewares
# 9            10            Artie Choke     Sales Associate            Hardware
# 10           11            Bette Alott     Sales Associate      Sporting Goods
# 11           12           Bill Melator     Sales Associate      Sporting Goods
# 12           13            Bob Enweave     Sales Associate      Sporting Goods
# 13           14        Chris P. Nugget     Sales Associate         Electronics
# 14           15            Chuck Itupp     Sales Associate      Sporting Goods
# 15           16           Detyers Erin     Sales Associate            Hardware
# 16           17               Kurt Tan     Sales Associate            Clothing
# 17           18            Justin Case    Sales Associate             Clothing
# 18           19           Kent Belevit     Sales Associate            Clothing
# 19           20                Mary Mi  Department Manager            Clothing
# 20           21              Maxi Mumm     Sales Associate         Electronics
# 21           22           Mike Rophone     Sales Associate          Housewares
# 22           23              Nat Tural     Sales Associate      Sporting Goods
# 23           24              Otto Moni  Department Manager          Housewares
# 24           25      Patty O'Furniture     Sales Associate          Housewares
# 25           26              Pete Moss     Sales Associate      Sporting Goods
# 26           27  Sara Docktur-Indahaus  Department Manager      Sporting Goods
# 27           28           Sara Isnomor     Sales Associate            Clothing
# 28           29          Seymour Ofewe     Sales Associate    Customer Service
# 29           30           Sonny Shores     Sales Associate    Customer Service
# 30           31            Tally Itupp  Department Manager    Customer Service
# 31           32           Tuck Androll       Store Manager    Customer Service
# 32           33             Mike Fudge                 CEO    Customer Service

# %%
cypher_merge = '''
MERGE (e:Employee
    {
        name: event.employee_name,
        dept: event.employee_department,
        jobtitle: event.employee_jobtitle,
        id: event.employee_id
    })
'''

tmp.write.format("org.neo4j.spark.DataSource").mode("Overwrite") \
    .option("url", bolt_url) \
    .option("query", cypher_merge) \
    .save()
print(cypher_merge)
# Out:
# MERGE (e:Employee
#     {
#         name: event.employee_name,
#         dept: event.employee_department,
#         jobtitle: event.employee_jobtitle,
#         id: event.employee_id
#     })

# %%
cypher_query = '''
MATCH (e:Employee)
RETURN e.name, e.dept, e.jobtitle, e.id;
'''
df = spark.read.format("org.neo4j.spark.DataSource") \
    .option("url", bolt_url) \
    .option("query", cypher_query) \
    .load()

df.show()
print(bolt_url)
# Out:
# +------------------+--------------+------------------+----+
# |            e.name|        e.dept|        e.jobtitle|e.id|
# +------------------+--------------+------------------+----+
# |       Arial Photo|   Electronics|   Sales Associate|   1|
# |          Sal Ladd|   Electronics|   Sales Associate|   2|
# |     Dustin Dawind|      Hardware|   Sales Associate|   3|
# |      Sandi Shores|      Hardware|   Sales Associate|   4|
# |Isabelle Gunnering|   Electronics|Department Manager|   5|
# |      Lee Hvmeehom|      Hardware|Department Manager|   6|
# |      Allan Wrench|    Housewares|   Sales Associate|   7|
# |        Ally Gator|Sporting Goods|   Sales Associate|   8|
# |  Alma Frienzergon|    Housewares|   Sales Associate|   9|
# |       Artie Choke|      Hardware|   Sales Associate|  10|
# |       Bette Alott|Sporting Goods|   Sales Associate|  11|
# |      Bill Melator|Sporting Goods|   Sales Associate|  12|
# |       Bob Enweave|Sporting Goods|   Sales Associate|  13|
# |   Chris P. Nugget|   Electronics|   Sales Associate|  14|
# |       Chuck Itupp|Sporting Goods|   Sales Associate|  15|
# |      Detyers Erin|      Hardware|   Sales Associate|  16|
# |          Kurt Tan|      Clothing|   Sales Associate|  17|
# |       Justin Case|      Clothing|  Sales Associate |  18|
# |      Kent Belevit|      Clothing|   Sales Associate|  19|
# |           Mary Mi|      Clothing|Department Manager|  20|
# +------------------+--------------+------------------+----+
# only showing top 20 rows
#
# bolt://neo4j:7687

# %%
cipher_sql = '''
MATCH(e:Employee)
MATCH(s:Employee)
WHERE e.id = event.employee_id AND s.id = event.employee_supervisor_id
MERGE (s)-[:SUPERVISES]->(e)
'''

sup_employee = employees.select("employee_supervisor_id", "employee_id").orderBy("employee_supervisor_id")
sup_employee.toPandas()

sup_employee.write.format("org.neo4j.spark.DataSource") \
    .mode("Overwrite") \
    .option("url", bolt_url) \
    .option("query", cipher_sql) \
    .save()
print(cipher_sql)
# Out:
# MATCH(e:Employee)
# MATCH(s:Employee)
# WHERE e.id = event.employee_id AND s.id = event.employee_supervisor_id
# MERGE (s)-[:SUPERVISES]->(e)
